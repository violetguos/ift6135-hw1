# %% [markdown]
# # Practical Part: Neural Network Implementation & Experiments\n",
# Team:
# * Jonathan Bhimani-Burrows (20178260)
# * Arlie Coles (20121051)
# * Yue (Violet) Guo (20120727)

# %% [markdown]
# # Note to TAs
# If you wish to re-run the training, please go to
# `src/scripts/q1_init_meth` for Q1 Initialization
# `src/scripts/q1_10_err` for Q1
# `src/scripts/q1_tuning` for Q1 hyperparameter search

# %%
import src.scripts.q1_10_err as q1_10_err
import src.scripts.q1_tuning as q1_tuning
import src.scripts.q1_hyper_gen as q1_hyper_gen
import src.scripts.q1_init_meth as q1_init_meth
import sys
import os

if __name__ == '__main__':
    print(os.getcwd())
    q1_init_meth.main([])

    q1_10_err.main([])
    q1_tuning.main([])
# Out:
# /Users/vikuo/Dropbox/1w/ift6135/devoir/assignment1/ift6135-hw1
